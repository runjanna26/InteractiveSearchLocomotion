# %%
import time
import pandas as pd
import json
from datetime import datetime
from datetime import timezone


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.ticker import ScalarFormatter
from matplotlib.colors import ListedColormap

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
leg_1_df_me = pd.read_csv('rbfn_joint_targets_withz_me_0.csv')
leg_2_df_me = pd.read_csv('rbfn_joint_targets_withz_me_1.csv')
leg_3_df_me = pd.read_csv('rbfn_joint_targets_withz_me_2.csv')

leg_1_df_si = pd.read_csv('rbfn_joint_targets_withz_si_0.csv')
leg_2_df_si = pd.read_csv('rbfn_joint_targets_withz_si_1.csv')
leg_3_df_si = pd.read_csv('rbfn_joint_targets_withz_si_2.csv')

# %%
fig = go.Figure()
fig = make_subplots(rows=4, cols=3, shared_xaxes=False)
fig.update_layout(height=800, width=1100, title="Path plot")
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))  # Reduce margins

# ME
fig.add_trace(go.Scatter( y=leg_1_df_me['tr'], mode='lines', name=f'TR1_1'), row=1, col=1)
fig.add_trace(go.Scatter( y=leg_1_df_me['cr'], mode='lines', name=f'CR1_1'), row=2, col=1)
fig.add_trace(go.Scatter( y=leg_1_df_me['fr'], mode='lines', name=f'FR1_1'), row=3, col=1)
fig.add_trace(go.Scatter( y=leg_1_df_me['z'], mode='lines', name=f'Z_1'), row=4, col=1)

fig.add_trace(go.Scatter( y=leg_2_df_me['tr'], mode='lines', name=f'TR1_2'), row=1, col=2)
fig.add_trace(go.Scatter( y=leg_2_df_me['cr'], mode='lines', name=f'CR1_2'), row=2, col=2)
fig.add_trace(go.Scatter( y=leg_2_df_me['fr'], mode='lines', name=f'FR1_2'), row=3, col=2)
fig.add_trace(go.Scatter( y=leg_2_df_me['z'], mode='lines', name=f'Z_2'), row=4, col=2)

fig.add_trace(go.Scatter( y=leg_3_df_me['tr'], mode='lines', name=f'TR1_3'), row=1, col=3)
fig.add_trace(go.Scatter( y=leg_3_df_me['cr'], mode='lines', name=f'CR1_3'), row=2, col=3)
fig.add_trace(go.Scatter( y=leg_3_df_me['fr'], mode='lines', name=f'FR1_3'), row=3, col=3)
fig.add_trace(go.Scatter( y=leg_3_df_me['z'], mode='lines', name=f'Z_3'), row=4, col=3)

# SI
fig.add_trace(go.Scatter( y=leg_1_df_si['tr'], mode='lines', name=f'TR1_1_si'), row=1, col=1)
fig.add_trace(go.Scatter( y=leg_1_df_si['cr'], mode='lines', name=f'CR1_1_si'), row=2, col=1)
fig.add_trace(go.Scatter( y=leg_1_df_si['fr'], mode='lines', name=f'FR1_1_si'), row=3, col=1)
fig.add_trace(go.Scatter( y=leg_1_df_si['z'], mode='lines',  name=f'Z_1_si'), row=4, col=1)

fig.add_trace(go.Scatter( y=leg_2_df_si['tr'], mode='lines', name=f'TR1_2_si'), row=1, col=2)
fig.add_trace(go.Scatter( y=leg_2_df_si['cr'], mode='lines', name=f'CR1_2_si'), row=2, col=2)
fig.add_trace(go.Scatter( y=leg_2_df_si['fr'], mode='lines', name=f'FR1_2_si'), row=3, col=2)
fig.add_trace(go.Scatter( y=leg_2_df_si['z'], mode='lines',  name=f'Z_2_si'), row=4, col=2)

fig.add_trace(go.Scatter( y=leg_3_df_si['tr'], mode='lines', name=f'TR1_3_si'), row=1, col=3)
fig.add_trace(go.Scatter( y=leg_3_df_si['cr'], mode='lines', name=f'CR1_3_si'), row=2, col=3)
fig.add_trace(go.Scatter( y=leg_3_df_si['fr'], mode='lines', name=f'FR1_3_si'), row=3, col=3)
fig.add_trace(go.Scatter( y=leg_3_df_si['z'], mode='lines',  name=f'Z_3_si'), row=4, col=3)
